# %% [markdown]
# # Lux AI Deep Reinforcement Learning Environment Example
# See https://github.com/glmcdona/LuxPythonEnvGym for environment project and updates.
#
# This is a python replica of the Lux game engine to speed up training. It reformats the agent problem into making a action decision per-unit for the team.

# %%
# !pip install git+https://github.com/glmcdona/LuxPythonEnvGym.git --no-deps
# !pip install kaggle-environments -U
# Out:
# Collecting git+https://github.com/glmcdona/LuxPythonEnvGym.git
#   Cloning https://github.com/glmcdona/LuxPythonEnvGym.git to /tmp/pip-req-build-opmalyxs
#   Running command git clone --filter=blob:none --quiet https://github.com/glmcdona/LuxPythonEnvGym.git /tmp/pip-req-build-opmalyxs
#   Resolved https://github.com/glmcdona/LuxPythonEnvGym.git to commit 55e8ddc15012fd55f17b23aa2e73c919467e43e3
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: luxai2021
#   Building wheel for luxai2021 (setup.py) ... done
#   Created wheel for luxai2021: filename=luxai2021-0.1.0-py3-none-any.whl size=46745 sha256=c766ad2e22828f71fe2b77be0ec56d3f7450aa3c35e873c37753123f7e419ab5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3c_xq9ke/wheels/76/fa/c5/51e3e7b28618516afcc384ba66a831716dd20a8e7947de83cf
# Successfully built luxai2021
# Installing collected packages: luxai2021
# Successfully installed luxai2021-0.1.0
# Collecting kaggle-environments
#   Downloading kaggle_environments-1.14.3-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: Flask>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from kaggle-environments) (2.2.5)
# Collecting gymnasium==0.29.0 (from kaggle-environments)
#   Downloading gymnasium-0.29.0-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.8/953.8 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from kaggle-environments) (4.19.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from kaggle-environments) (1.25.2)
# Collecting pettingzoo==1.24.0 (from kaggle-environments)
#   Downloading pettingzoo-1.24.0-py3-none-any.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.10/dist-packages (from kaggle-environments) (2.31.0)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from kaggle-environments) (1.11.4)
# Collecting shimmy>=1.2.1 (from kaggle-environments)
#   Downloading Shimmy-1.3.0-py3-none-any.whl (37 kB)
# Collecting stable-baselines3==2.1.0 (from kaggle-environments)
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 22.4 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.33.1 in /usr/local/lib/python3.10/dist-packages (from kaggle-environments) (4.38.2)
# Collecting vec-noise>=1.1.4 (from kaggle-environments)
#   Downloading vec_noise-1.1.4.zip (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.1/134.1 kB 15.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.29.0->kaggle-environments) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.29.0->kaggle-environments) (4.10.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.29.0->kaggle-environments)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.1.0->kaggle-environments) (2.2.1+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.1.0->kaggle-environments) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.1.0->kaggle-environments) (3.7.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->kaggle-environments) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->kaggle-environments) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->kaggle-environments) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask>=1.1.2->kaggle-environments) (8.1.7)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->kaggle-environments) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->kaggle-environments) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->kaggle-environments) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0.1->kaggle-environments) (0.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->kaggle-environments) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->kaggle-environments) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->kaggle-environments) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.1->kaggle-environments) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.1->kaggle-environments) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.1->kaggle-environments) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.1->kaggle-environments) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.1->kaggle-environments) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.1->kaggle-environments) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.1->kaggle-environments) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.1->kaggle-environments) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.33.1->kaggle-environments) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.33.1->kaggle-environments) (2023.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask>=1.1.2->kaggle-environments) (2.1.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments) (3.2.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 33.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 52.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 26.0 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.8 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 9.5 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3==2.1.0->kaggle-environments) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3==2.1.0->kaggle-environments)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 70.8 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.1.0->kaggle-environments) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.1.0->kaggle-environments) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.1.0->kaggle-environments) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.1.0->kaggle-environments) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.1.0->kaggle-environments) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.1.0->kaggle-environments) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.1.0->kaggle-environments) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.1.0->kaggle-environments) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.1.0->kaggle-environments) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3==2.1.0->kaggle-environments) (1.3.0)
# Building wheels for collected packages: vec-noise
#   Building wheel for vec-noise (setup.py) ... done
#   Created wheel for vec-noise: filename=vec_noise-1.1.4-cp310-cp310-linux_x86_64.whl size=73646 sha256=3ff53b063845915342687992c036cad8549a5b305c790b3c376cd86a22dd4975
#   Stored in directory: /root/.cache/pip/wheels/2b/28/e4/f710af1a5bb24bb6da3d4f65081e268ca85034b7ac0a9237fe
# Successfully built vec-noise
# Installing collected packages: farama-notifications, vec-noise, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, gymnasium, shimmy, pettingzoo, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3, kaggle-environments
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# luxai2021 0.1.0 requires gym==0.19.0, but you have gym 0.25.2 which is incompatible.
# luxai2021 0.1.0 requires stable-baselines3==1.2.1a2, but you have stable-baselines3 2.1.0 which is incompatible.
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.0 kaggle-environments-1.14.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 pettingzoo-1.24.0 shimmy-1.3.0 stable-baselines3-2.1.0 vec-noise-1.1.4

# %% [markdown]
# ## Use GPU if available
# Note: GPU provides very little speedup. I recommend using a CPU-only notebook usually.

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
print(device)
# Out:
# cpu

# %% [markdown]
# # Define the RL agent logic
# Edit this agent logic to implement your own observations, action space, and reward shaping.

# %%
# %%writefile agent_policy.py
from luxai2021.game.match_controller import ActionSequence
import sys
import time
from functools import partial  # pip install functools

import numpy as np
from gym import spaces
import copy
import random

from luxai2021.env.agent import Agent
from luxai2021.game.actions import *
from luxai2021.game.game_constants import GAME_CONSTANTS
from luxai2021.game.position import Position


# https://codereview.stackexchange.com/questions/28207/finding-the-closest-point-to-a-list-of-points
def closest_node(node, nodes):
    dist_2 = np.sum((nodes - node) ** 2, axis=1)
    return np.argmin(dist_2)
def furthest_node(node, nodes):
    dist_2 = np.sum((nodes - node) ** 2, axis=1)
    return np.argmax(dist_2)

def smart_transfer_to_nearby(game, team, unit_id, unit, target_type_restriction=None, **kwarg):
    """
    Smart-transfers from the specified unit to a nearby neighbor. Prioritizes any
    nearby carts first, then any worker. Transfers the resource type which the unit
    has most of. Picks which cart/worker based on choosing a target that is most-full
    but able to take the most amount of resources.

    Args:
        team ([type]): [description]
        unit_id ([type]): [description]

    Returns:
        Action: Returns a TransferAction object, even if the request is an invalid
                transfer. Use TransferAction.is_valid() to check validity.
    """

    # Calculate how much resources could at-most be transferred
    resource_type = None
    resource_amount = 0
    target_unit = None

    if unit != None:
        for type, amount in unit.cargo.items():
            if amount > resource_amount:
                resource_type = type
                resource_amount = amount

        # Find the best nearby unit to transfer to
        unit_cell = game.map.get_cell_by_pos(unit.pos)
        adjacent_cells = game.map.get_adjacent_cells(unit_cell)


        for c in adjacent_cells:
            for id, u in c.units.items():
                # Apply the unit type target restriction
                if target_type_restriction == None or u.type == target_type_restriction:
                    if u.team == team:
                        # This unit belongs to our team, set it as the winning transfer target
                        # if it's the best match.
                        if target_unit is None:
                            target_unit = u
                        else:
                            # Compare this unit to the existing target
                            if target_unit.type == u.type:
                                # Transfer to the target with the least capacity, but can accept
                                # all of our resources
                                if( u.get_cargo_space_left() >= resource_amount and
                                    target_unit.get_cargo_space_left() >= resource_amount ):
                                    # Both units can accept all our resources. Prioritize one that is most-full.
                                    if u.get_cargo_space_left() < target_unit.get_cargo_space_left():
                                        # This new target it better, it has less space left and can take all our
                                        # resources
                                        target_unit = u

                                elif( target_unit.get_cargo_space_left() >= resource_amount ):
                                    # Don't change targets. Current one is best since it can take all
                                    # the resources, but new target can't.
                                    pass

                                elif( u.get_cargo_space_left() > target_unit.get_cargo_space_left() ):
                                    # Change targets, because neither target can accept all our resources and
                                    # this target can take more resources.
                                    target_unit = u
                            elif u.type == Constants.UNIT_TYPES.CART:
                                # Transfer to this cart instead of the current worker target
                                target_unit = u

    # Build the transfer action request
    target_unit_id = None
    if target_unit is not None:
        target_unit_id = target_unit.id

        # Update the transfer amount based on the room of the target
        if target_unit.get_cargo_space_left() < resource_amount:
            resource_amount = target_unit.get_cargo_space_left()

    return TransferAction(team, unit_id, target_unit_id, resource_type, resource_amount)

########################################################################################################################
# This is the Agent that you need to design for the competition
########################################################################################################################
class AgentPolicy(Agent):
    def __init__(self, mode="train", model=None) -> None:
        """
        Arguments:
            mode: "train" or "inference", which controls if this agent is for training or not.
            model: The pretrained model, or if None it will operate in training mode.
        """
        super().__init__()
        self.model = model
        self.mode = mode

        self.stats = None
        self.stats_last_game = None

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions:
        self.actionSpaceMapUnits = [
            partial(MoveAction, direction=Constants.DIRECTIONS.CENTER),  # This is the do-nothing action
            partial(MoveAction, direction=Constants.DIRECTIONS.NORTH),
            partial(MoveAction, direction=Constants.DIRECTIONS.WEST),
            partial(MoveAction, direction=Constants.DIRECTIONS.SOUTH),
            partial(MoveAction, direction=Constants.DIRECTIONS.EAST),
            smart_transfer_to_nearby, # Transfer to nearby
            SpawnCityAction,
            #PillageAction,
        ]
        self.actionSpaceMapCities = [
            SpawnWorkerAction,
            SpawnCartAction,
            ResearchAction,
        ]

        self.action_space = spaces.Discrete(max(len(self.actionSpaceMapUnits), len(self.actionSpaceMapCities)))


        # Observation space: (Basic minimum for a miner agent)
        # Object:
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        #
        #   5x direction_nearest_wood
        #   1x distance_nearest_wood
        #   1x amount
        #
        #   5x direction_nearest_coal
        #   1x distance_nearest_coal
        #   1x amount
        #
        #   5x direction_nearest_uranium
        #   1x distance_nearest_uranium
        #   1x amount
        #
        #   5x direction_nearest_city
        #   1x distance_nearest_city
        #   1x amount of fuel
        #
        #   28x (the same as above, but direction, distance, and amount to the furthest of each)
        #
        #   5x direction_nearest_worker
        #   1x distance_nearest_worker
        #   1x amount of cargo
        # Unit:
        #   1x cargo size
        # State:
        #   1x is night
        #   1x percent of game done
        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        self.observation_shape = (3 + 7 * 5 * 2 + 1 + 1 + 1 + 2 + 2 + 2 + 3,)
        self.observation_space = spaces.Box(low=0, high=1, shape=
        self.observation_shape, dtype=np.float16)

        self.object_nodes = {}

    def get_agent_type(self):
        """
        Returns the type of agent. Use AGENT for inference, and LEARNING for training a model.
        """
        if self.mode == "train":
            return Constants.AGENT_TYPE.LEARNING
        else:
            return Constants.AGENT_TYPE.AGENT

    def get_observation(self, game, unit, city_tile, team, is_new_turn):
        """
        Implements getting a observation from the current game for this unit or city
        """
        observation_index = 0
        if is_new_turn:
            # It's a new turn this event. This flag is set True for only the first observation from each turn.
            # Update any per-turn fixed observation space that doesn't change per unit/city controlled.

            # Build a list of object nodes by type for quick distance-searches
            self.object_nodes = {}

            # Add resources
            for cell in game.map.resources:
                if cell.resource.type not in self.object_nodes:
                    self.object_nodes[cell.resource.type] = np.array([[cell.pos.x, cell.pos.y]])
                else:
                    self.object_nodes[cell.resource.type] = np.concatenate(
                        (
                            self.object_nodes[cell.resource.type],
                            [[cell.pos.x, cell.pos.y]]
                        ),
                        axis=0
                    )

            # Add your own and opponent units
            for t in [team, (team + 1) % 2]:
                for u in game.state["teamStates"][team]["units"].values():
                    key = str(u.type)
                    if t != team:
                        key = str(u.type) + "_opponent"

                    if key not in self.object_nodes:
                        self.object_nodes[key] = np.array([[u.pos.x, u.pos.y]])
                    else:
                        self.object_nodes[key] = np.concatenate(
                            (
                                self.object_nodes[key],
                                [[u.pos.x, u.pos.y]]
                            )
                            , axis=0
                        )

            # Add your own and opponent cities
            for city in game.cities.values():
                for cells in city.city_cells:
                    key = "city"
                    if city.team != team:
                        key = "city_opponent"

                    if key not in self.object_nodes:
                        self.object_nodes[key] = np.array([[cells.pos.x, cells.pos.y]])
                    else:
                        self.object_nodes[key] = np.concatenate(
                            (
                                self.object_nodes[key],
                                [[cells.pos.x, cells.pos.y]]
                            )
                            , axis=0
                        )

        # Observation space: (Basic minimum for a miner agent)
        # Object:
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        #   5x direction_nearest_wood
        #   1x distance_nearest_wood
        #   1x amount
        #
        #   5x direction_nearest_coal
        #   1x distance_nearest_coal
        #   1x amount
        #
        #   5x direction_nearest_uranium
        #   1x distance_nearest_uranium
        #   1x amount
        #
        #   5x direction_nearest_city
        #   1x distance_nearest_city
        #   1x amount of fuel
        #
        #   5x direction_nearest_worker
        #   1x distance_nearest_worker
        #   1x amount of cargo
        #
        #   28x (the same as above, but direction, distance, and amount to the furthest of each)
        #
        # Unit:
        #   1x cargo size
        # State:
        #   1x is night
        #   1x percent of game done
        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        obs = np.zeros(self.observation_shape)

        # Update the type of this object
        #   1x is worker
        #   1x is cart
        #   1x is citytile
        observation_index = 0
        if unit is not None:
            if unit.type == Constants.UNIT_TYPES.WORKER:
                obs[observation_index] = 1.0 # Worker
            else:
                obs[observation_index+1] = 1.0 # Cart
        if city_tile is not None:
            obs[observation_index+2] = 1.0 # CityTile
        observation_index += 3

        pos = None
        if unit is not None:
            pos = unit.pos
        else:
            pos = city_tile.pos

        if pos is None:
            observation_index += 7 * 5 * 2
        else:
            # Encode the direction to the nearest objects
            #   5x direction_nearest
            #   1x distance
            for distance_function in [closest_node, furthest_node]:
                for key in [
                    Constants.RESOURCE_TYPES.WOOD,
                    Constants.RESOURCE_TYPES.COAL,
                    Constants.RESOURCE_TYPES.URANIUM,
                    "city",
                    str(Constants.UNIT_TYPES.WORKER)]:
                    # Process the direction to and distance to this object type

                    # Encode the direction to the nearest object (excluding itself)
                    #   5x direction
                    #   1x distance
                    if key in self.object_nodes:
                        if (
                                (key == "city" and city_tile is not None) or
                                (unit is not None and str(unit.type) == key and len(game.map.get_cell_by_pos(unit.pos).units) <= 1 )
                        ):
                            # Filter out the current unit from the closest-search
                            closest_index = closest_node((pos.x, pos.y), self.object_nodes[key])
                            filtered_nodes = np.delete(self.object_nodes[key], closest_index, axis=0)
                        else:
                            filtered_nodes = self.object_nodes[key]

                        if len(filtered_nodes) == 0:
                            # No other object of this type
                            obs[observation_index + 5] = 1.0
                        else:
                            # There is another object of this type
                            closest_index = distance_function((pos.x, pos.y), filtered_nodes)

                            if closest_index is not None and closest_index >= 0:
                                closest = filtered_nodes[closest_index]
                                closest_position = Position(closest[0], closest[1])
                                direction = pos.direction_to(closest_position)
                                mapping = {
                                    Constants.DIRECTIONS.CENTER: 0,
                                    Constants.DIRECTIONS.NORTH: 1,
                                    Constants.DIRECTIONS.WEST: 2,
                                    Constants.DIRECTIONS.SOUTH: 3,
                                    Constants.DIRECTIONS.EAST: 4,
                                }
                                obs[observation_index + mapping[direction]] = 1.0  # One-hot encoding direction

                                # 0 to 1 distance
                                distance = pos.distance_to(closest_position)
                                obs[observation_index + 5] = min(distance / 20.0, 1.0)

                                # 0 to 1 value (amount of resource, cargo for unit, or fuel for city)
                                if key == "city":
                                    # City fuel as % of upkeep for 200 turns
                                    c = game.cities[game.map.get_cell_by_pos(closest_position).city_tile.city_id]
                                    obs[observation_index + 6] = min(
                                        c.fuel / (c.get_light_upkeep() * 200.0),
                                        1.0
                                    )
                                elif key in [Constants.RESOURCE_TYPES.WOOD, Constants.RESOURCE_TYPES.COAL,
                                             Constants.RESOURCE_TYPES.URANIUM]:
                                    # Resource amount
                                    obs[observation_index + 6] = min(
                                        game.map.get_cell_by_pos(closest_position).resource.amount / 500,
                                        1.0
                                    )
                                else:
                                    # Unit cargo
                                    obs[observation_index + 6] = min(
                                        next(iter(game.map.get_cell_by_pos(
                                            closest_position).units.values())).get_cargo_space_left() / 100,
                                        1.0
                                    )

                    observation_index += 7

        if unit is not None:
            # Encode the cargo space
            #   1x cargo size
            obs[observation_index] = unit.get_cargo_space_left() / GAME_CONSTANTS["PARAMETERS"]["RESOURCE_CAPACITY"][
                "WORKER"]
            observation_index += 1
        else:
            observation_index += 1

        # Game state observations

        #   1x is night
        obs[observation_index] = game.is_night()
        observation_index += 1

        #   1x percent of game done
        obs[observation_index] = game.state["turn"] / GAME_CONSTANTS["PARAMETERS"]["MAX_DAYS"]
        observation_index += 1

        #   2x citytile counts [cur player, opponent]
        #   2x worker counts [cur player, opponent]
        #   2x cart counts [cur player, opponent]
        max_count = 30
        for key in ["city", str(Constants.UNIT_TYPES.WORKER), str(Constants.UNIT_TYPES.CART)]:
            if key in self.object_nodes:
                obs[observation_index] = len(self.object_nodes[key]) / max_count
            if (key + "_opponent") in self.object_nodes:
                obs[observation_index + 1] = len(self.object_nodes[(key + "_opponent")]) / max_count
            observation_index += 2

        #   1x research points [cur player]
        #   1x researched coal [cur player]
        #   1x researched uranium [cur player]
        obs[observation_index] = game.state["teamStates"][team]["researchPoints"] / 200.0
        obs[observation_index+1] = float(game.state["teamStates"][team]["researched"]["coal"])
        obs[observation_index+2] = float(game.state["teamStates"][team]["researched"]["uranium"])

        return obs

    def action_code_to_action(self, action_code, game, unit=None, city_tile=None, team=None):
        """
        Takes an action in the environment according to actionCode:
            actionCode: Index of action to take into the action array.
        Returns: An action.
        """
        # Map actionCode index into to a constructed Action object
        try:
            x = None
            y = None
            if city_tile is not None:
                x = city_tile.pos.x
                y = city_tile.pos.y
            elif unit is not None:
                x = unit.pos.x
                y = unit.pos.y

            if city_tile != None:
                action =  self.actionSpaceMapCities[action_code%len(self.actionSpaceMapCities)](
                    game=game,
                    unit_id=unit.id if unit else None,
                    unit=unit,
                    city_id=city_tile.city_id if city_tile else None,
                    citytile=city_tile,
                    team=team,
                    x=x,
                    y=y
                )

                # If the city action is invalid, default to research action automatically
                if not action.is_valid(game, actions_validated=[]):
                    action = ResearchAction(
                        game=game,
                        unit_id=unit.id if unit else None,
                        unit=unit,
                        city_id=city_tile.city_id if city_tile else None,
                        citytile=city_tile,
                        team=team,
                        x=x,
                        y=y
                    )
            else:
                action =  self.actionSpaceMapUnits[action_code%len(self.actionSpaceMapUnits)](
                    game=game,
                    unit_id=unit.id if unit else None,
                    unit=unit,
                    city_id=city_tile.city_id if city_tile else None,
                    citytile=city_tile,
                    team=team,
                    x=x,
                    y=y
                )

            return action
        except Exception as e:
            # Not a valid action
            print(e)
            return None

    def take_action(self, action_code, game, unit=None, city_tile=None, team=None):
        """
        Takes an action in the environment according to actionCode:
            actionCode: Index of action to take into the action array.
        """
        action = self.action_code_to_action(action_code, game, unit, city_tile, team)
        self.match_controller.take_action(action)

    def game_start(self, game):
        """
        This funciton is called at the start of each game. Use this to
        reset and initialize per game. Note that self.team may have
        been changed since last game. The game map has been created
        and starting units placed.

        Args:
            game ([type]): Game.
        """
        self.last_generated_fuel = game.stats["teamStats"][self.team]["fuelGenerated"]
        self.last_resources_collected = copy.deepcopy(game.stats["teamStats"][self.team]["resourcesCollected"])
        if self.stats != None:
            self.stats_last_game =  self.stats
        self.stats = {
            "rew/r_total": 0,
            "rew/r_wood": 0,
            "rew/r_coal": 0,
            "rew/r_uranium": 0,
            "rew/r_research": 0,
            "rew/r_city_tiles_end": 0,
            "rew/r_fuel_collected":0,
            "rew/r_units":0,
            "rew/r_city_tiles":0,
            "game/turns": 0,
            "game/research": 0,
            "game/unit_count": 0,
            "game/cart_count": 0,
            "game/city_count": 0,
            "game/city_tiles": 0,
            "game/wood_rate_mined": 0,
            "game/coal_rate_mined": 0,
            "game/uranium_rate_mined": 0,
        }
        self.is_last_turn = False

        # Calculate starting map resources
        type_map = {
            Constants.RESOURCE_TYPES.WOOD: "WOOD",
            Constants.RESOURCE_TYPES.COAL: "COAL",
            Constants.RESOURCE_TYPES.URANIUM: "URANIUM",
        }

        self.fuel_collected_last = 0
        self.fuel_start = {}
        self.fuel_last = {}
        for type, type_upper in type_map.items():
            self.fuel_start[type] = 0
            self.fuel_last[type] = 0
            for c in game.map.resources_by_type[type]:
                self.fuel_start[type] += c.resource.amount * game.configs["parameters"]["RESOURCE_TO_FUEL_RATE"][type_upper]

        self.research_last = 0
        self.units_last = 0
        self.city_tiles_last = 0

    def get_reward(self, game, is_game_finished, is_new_turn, is_game_error):
        """
        Returns the reward function for this step of the game.
        """
        if is_game_error:
            # Game environment step failed, assign a game lost reward to not incentivise this
            print("Game failed due to error")
            return -1.0

        if not is_new_turn and not is_game_finished:
            # Only apply rewards at the start of each turn
            return 0

        # Get some basic stats
        unit_count = len(game.state["teamStates"][self.team % 2]["units"])
        cart_count = 0
        for id, u in game.state["teamStates"][self.team % 2]["units"].items():
            if u.type == Constants.UNIT_TYPES.CART:
                cart_count += 1

        unit_count_opponent = len(game.state["teamStates"][(self.team + 1) % 2]["units"])
        research = min(game.state["teamStates"][self.team]["researchPoints"], 200.0) # Cap research points at 200
        city_count = 0
        city_count_opponent = 0
        city_tile_count = 0
        city_tile_count_opponent = 0
        for city in game.cities.values():
            if city.team == self.team:
                city_count += 1
            else:
                city_count_opponent += 1

            for cell in city.city_cells:
                if city.team == self.team:
                    city_tile_count += 1
                else:
                    city_tile_count_opponent += 1

        # Basic stats
        self.stats["game/research"] = research
        self.stats["game/city_tiles"] = city_tile_count
        self.stats["game/city_count"] = city_count
        self.stats["game/unit_count"] = unit_count
        self.stats["game/cart_count"] = cart_count
        self.stats["game/turns"] = game.state["turn"]

        rewards = {}

        # Give up to 1.0 reward for each resource based on % of total mined.
        type_map = {
            Constants.RESOURCE_TYPES.WOOD: "WOOD",
            Constants.RESOURCE_TYPES.COAL: "COAL",
            Constants.RESOURCE_TYPES.URANIUM: "URANIUM",
        }
        fuel_now = {}
        for type, type_upper in type_map.items():
            fuel_now = game.stats["teamStats"][self.team]["resourcesCollected"][type] * game.configs["parameters"]["RESOURCE_TO_FUEL_RATE"][type_upper]
            rewards["rew/r_%s" % type] = (fuel_now - self.fuel_last[type]) / self.fuel_start[type]
            self.stats["game/%s_rate_mined" % type] = fuel_now / self.fuel_start[type]
            self.fuel_last[type] = fuel_now

        # Give more incentive for coal and uranium
        rewards["rew/r_%s" % Constants.RESOURCE_TYPES.COAL] *= 2
        rewards["rew/r_%s" % Constants.RESOURCE_TYPES.URANIUM] *= 4

        # Give a reward based on amount of fuel collected. 1.0 reward for each 20K fuel gathered.
        fuel_collected = game.stats["teamStats"][self.team]["fuelGenerated"]
        rewards["rew/r_fuel_collected"] = ( (fuel_collected - self.fuel_collected_last) / 20000 )
        self.fuel_collected_last = fuel_collected

        # Give a reward for unit creation/death. 0.05 reward per unit.
        rewards["rew/r_units"] = (unit_count - self.units_last) * 0.05
        self.units_last = unit_count

        # Give a reward for unit creation/death. 0.1 reward per city.
        rewards["rew/r_city_tiles"] = (city_tile_count - self.city_tiles_last) * 0.1
        self.city_tiles_last = city_tile_count

        # Tiny reward for research to help. Up to 0.5 reward for this.
        rewards["rew/r_research"] = (research - self.research_last) / (200 * 2)
        self.research_last = research

        # Give a reward up to around 50.0 based on number of city tiles at the end of the game
        rewards["rew/r_city_tiles_end"] = 0
        if is_game_finished:
            self.is_last_turn = True
            rewards["rew/r_city_tiles_end"] = city_tile_count


        # Update the stats and total reward
        reward = 0
        for name, value in rewards.items():
            self.stats[name] += value
            reward += value
        self.stats["rew/r_total"] += reward

        # Print the final game stats sometimes
        if is_game_finished and random.random() <= 0.15:
            stats_string = []
            for key, value in self.stats.items():
                stats_string.append("%s=%.2f" % (key, value))
            print(",".join(stats_string))


        return reward



    def process_turn(self, game, team):
        """
        Decides on a set of actions for the current turn. Not used in training, only inference.
        Returns: Array of actions to perform.
        """
        start_time = time.time()
        actions = []
        new_turn = True

        # Inference the model per-unit
        units = game.state["teamStates"][team]["units"].values()
        for unit in units:
            if unit.can_act():
                obs = self.get_observation(game, unit, None, unit.team, new_turn)
                action_code, _states = self.model.predict(obs, deterministic=False)
                if action_code is not None:
                    actions.append(
                        self.action_code_to_action(action_code, game=game, unit=unit, city_tile=None, team=unit.team))
                new_turn = False

        # Inference the model per-city
        cities = game.cities.values()
        for city in cities:
            if city.team == team:
                for cell in city.city_cells:
                    city_tile = cell.city_tile
                    if city_tile.can_act():
                        obs = self.get_observation(game, None, city_tile, city.team, new_turn)
                        action_code, _states = self.model.predict(obs, deterministic=False)
                        if action_code is not None:
                            actions.append(
                                self.action_code_to_action(action_code, game=game, unit=None, city_tile=city_tile,
                                                           team=city.team))
                        new_turn = False

        time_taken = time.time() - start_time
        if time_taken > 0.5:  # Warn if larger than 0.5 seconds.
            print("WARNING: Inference took %.3f seconds for computing actions. Limit is 1 second." % time_taken,
                  file=sys.stderr)

        return actions
# Out:
# Writing agent_policy.py

# %% [markdown]
# # Build the environment for training
#
# Notes on metrics:
# * An Episode is a single game between your RL agent and it's opponent. This is generally 360 turns, spanning more than 360 unit + city decision steps.
# * Mean episode length (ep_len_mean) is the number of decision made per game. The larger this gets, means that it is making more unit + city decision per game, meaning that more units and cities were alive for longer during the game.
# * Episode reward mean (ep_rew_mean), is set up as micro-reward funciton for faster learning. Per turn it gets a small reward based on the number of cities and units alive. It gets a really big reward based on the number of cities and units alive at the end of the game.

# %%
import argparse
import glob
import os
import random
from typing import Callable

from stable_baselines3 import PPO  # pip install stable-baselines3
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.vec_env import SubprocVecEnv

from importlib import reload
import agent_policy
reload(agent_policy) # Reload the file from disk incase the above agent-writing cell block was edited
from agent_policy import AgentPolicy

from luxai2021.env.agent import Agent
from luxai2021.env.lux_env import LuxEnvironment
from luxai2021.game.constants import LuxMatchConfigs_Default


# Default Lux configs
configs = LuxMatchConfigs_Default

# Create a default opponent agent
opponent = Agent()

# Create a RL agent in training mode
player = AgentPolicy(mode="train")

# Create the Lux environment
env = LuxEnvironment(configs=configs,
                     learning_agent=player,
                     opponent_agent=opponent)

# Define the model, you can pick other RL algos from Stable Baselines3 instead if you like
model = PPO("MlpPolicy",
                env,
                verbose=1,
                tensorboard_log="./lux_tensorboard/",
                learning_rate=0.001,
                gamma=0.999,
                gae_lambda=0.95,
                batch_size=2048 * 8,
                n_steps=2048 * 8
            )

# Define a learning rate schedule
# (number of steps, learning_rate)
schedule = [
    #(2000000, 0.01),
    (6000000, 0.001),
    (6000000, 0.0001),
]
# Out:
# Running in inference-only mode.
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# # Train the agent against a dummy opponent

# %%
from stable_baselines3.common.utils import get_schedule_fn

print("Training model...")
run_id = 1

# Save a checkpoint every 1M steps
checkpoint_callback = CheckpointCallback(save_freq=1000000,
                                         save_path='./models/',
                                         name_prefix=f'rl_model_{run_id}')

# Train the policy
for steps, learning_rate in schedule:
    model.lr_schedule = get_schedule_fn(learning_rate)
    model.learn(total_timesteps=steps,
                callback=checkpoint_callback,
                reset_num_timesteps = False)

# Save final model
model.save(path=f'models/model.zip')

print("Done training model.")
# Out:
# Streaming output truncated to the last 5000 lines.
# rew/r_total=11.76,rew/r_wood=0.78,rew/r_coal=0.01,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=9.00,rew/r_fuel_collected=0.13,rew/r_units=0.45,rew/r_city_tiles=0.90,game/turns=360.00,game/research=200.00,game/unit_count=9.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=9.00,game/wood_rate_mined=0.78,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=17.81,rew/r_wood=0.34,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.21,rew/r_city_tiles_end=15.00,rew/r_fuel_collected=0.10,rew/r_units=0.65,rew/r_city_tiles=1.50,game/turns=198.00,game/research=84.00,game/unit_count=13.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=15.00,game/wood_rate_mined=0.34,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.89e+03     |
# |    ep_rew_mean          | 6.91         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 142          |
# |    time_elapsed         | 3593         |
# |    total_timesteps      | 8339456      |
# | train/                  |              |
# |    approx_kl            | 0.0006566611 |
# |    clip_fraction        | 0.00458      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.179       |
# |    explained_variance   | 0.308        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.331        |
# |    n_updates            | 5080         |
# |    policy_gradient_loss | -0.000303    |
# |    value_loss           | 0.666        |
# ------------------------------------------
# rew/r_total=0.88,rew/r_wood=0.55,rew/r_coal=0.01,rew/r_uranium=0.00,rew/r_research=0.25,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.07,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=120.00,game/research=101.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.55,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=11.56,rew/r_wood=0.80,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.23,rew/r_city_tiles_end=9.00,rew/r_fuel_collected=0.13,rew/r_units=0.50,rew/r_city_tiles=0.90,game/turns=198.00,game/research=93.00,game/unit_count=10.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=9.00,game/wood_rate_mined=0.80,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.89e+03     |
# |    ep_rew_mean          | 6.72         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 143          |
# |    time_elapsed         | 3618         |
# |    total_timesteps      | 8355840      |
# | train/                  |              |
# |    approx_kl            | 0.0014128475 |
# |    clip_fraction        | 0.00656      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | 0.427        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.148        |
# |    n_updates            | 5090         |
# |    policy_gradient_loss | -0.000403    |
# |    value_loss           | 0.3          |
# ------------------------------------------
# rew/r_total=1.71,rew/r_wood=1.18,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.43,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.11,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=234.00,game/research=171.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=1.18,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=2.02,rew/r_wood=1.39,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.49,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.14,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=351.00,game/research=195.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=1.39,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=3.58,rew/r_wood=0.66,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.42,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.16,rew/r_units=0.15,rew/r_city_tiles=0.20,game/turns=198.00,game/research=166.00,game/unit_count=3.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=2.00,game/wood_rate_mined=0.66,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.87e+03      |
# |    ep_rew_mean          | 7.06          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 144           |
# |    time_elapsed         | 3643          |
# |    total_timesteps      | 8372224       |
# | train/                  |               |
# |    approx_kl            | 0.00032019164 |
# |    clip_fraction        | 0.00033       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.246        |
# |    explained_variance   | 0.467         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.122         |
# |    n_updates            | 5100          |
# |    policy_gradient_loss | -0.000174     |
# |    value_loss           | 0.245         |
# -------------------------------------------
# rew/r_total=3.99,rew/r_wood=0.29,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.17,rew/r_city_tiles_end=3.00,rew/r_fuel_collected=0.09,rew/r_units=0.15,rew/r_city_tiles=0.30,game/turns=198.00,game/research=66.00,game/unit_count=3.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=3.00,game/wood_rate_mined=0.29,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=3.65,rew/r_wood=0.91,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.27,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.12,rew/r_units=0.15,rew/r_city_tiles=0.20,game/turns=198.00,game/research=109.00,game/unit_count=3.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=2.00,game/wood_rate_mined=0.91,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=19.04,rew/r_wood=1.02,rew/r_coal=0.05,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=15.00,rew/r_fuel_collected=0.22,rew/r_units=0.75,rew/r_city_tiles=1.50,game/turns=360.00,game/research=200.00,game/unit_count=15.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=15.00,game/wood_rate_mined=1.02,game/coal_rate_mined=0.02,game/uranium_rate_mined=0.00
# rew/r_total=4.59,rew/r_wood=1.39,rew/r_coal=0.16,rew/r_uranium=0.03,rew/r_research=0.50,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.16,rew/r_units=0.15,rew/r_city_tiles=0.20,game/turns=198.00,game/research=200.00,game/unit_count=3.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=2.00,game/wood_rate_mined=1.39,game/coal_rate_mined=0.08,game/uranium_rate_mined=0.01
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.85e+03     |
# |    ep_rew_mean          | 6.83         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 145          |
# |    time_elapsed         | 3669         |
# |    total_timesteps      | 8388608      |
# | train/                  |              |
# |    approx_kl            | 0.0019881472 |
# |    clip_fraction        | 0.00924      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.27        |
# |    explained_variance   | 0.327        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.202        |
# |    n_updates            | 5110         |
# |    policy_gradient_loss | -0.000412    |
# |    value_loss           | 0.408        |
# ------------------------------------------
# rew/r_total=0.75,rew/r_wood=0.31,rew/r_coal=0.12,rew/r_uranium=0.00,rew/r_research=0.18,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.09,rew/r_units=0.05,rew/r_city_tiles=-0.00,game/turns=360.00,game/research=73.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.31,game/coal_rate_mined=0.06,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.89e+03      |
# |    ep_rew_mean          | 7.02          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 146           |
# |    time_elapsed         | 3693          |
# |    total_timesteps      | 8404992       |
# | train/                  |               |
# |    approx_kl            | 0.00088335545 |
# |    clip_fraction        | 0.00247       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.256        |
# |    explained_variance   | 0.459         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.141         |
# |    n_updates            | 5120          |
# |    policy_gradient_loss | -0.000318     |
# |    value_loss           | 0.285         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.89e+03      |
# |    ep_rew_mean          | 7.25          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 147           |
# |    time_elapsed         | 3718          |
# |    total_timesteps      | 8421376       |
# | train/                  |               |
# |    approx_kl            | 0.00039656865 |
# |    clip_fraction        | 0.00022       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.235        |
# |    explained_variance   | 0.39          |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.193         |
# |    n_updates            | 5130          |
# |    policy_gradient_loss | -9.34e-05     |
# |    value_loss           | 0.39          |
# -------------------------------------------
# rew/r_total=1.23,rew/r_wood=0.91,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.24,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.09,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=357.00,game/research=94.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.91,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.91e+03   |
# |    ep_rew_mean          | 7.1        |
# | time/                   |            |
# |    fps                  | 647        |
# |    iterations           | 148        |
# |    time_elapsed         | 3743       |
# |    total_timesteps      | 8437760    |
# | train/                  |            |
# |    approx_kl            | 0.00094503 |
# |    clip_fraction        | 0.00277    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.237     |
# |    explained_variance   | 0.788      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.054      |
# |    n_updates            | 5140       |
# |    policy_gradient_loss | -0.000368  |
# |    value_loss           | 0.111      |
# ----------------------------------------
# rew/r_total=12.18,rew/r_wood=1.11,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=9.00,rew/r_fuel_collected=0.22,rew/r_units=0.45,rew/r_city_tiles=0.90,game/turns=360.00,game/research=200.00,game/unit_count=9.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=9.00,game/wood_rate_mined=1.11,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.95e+03      |
# |    ep_rew_mean          | 7.11          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 149           |
# |    time_elapsed         | 3768          |
# |    total_timesteps      | 8454144       |
# | train/                  |               |
# |    approx_kl            | 0.00017573258 |
# |    clip_fraction        | 1.83e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.221        |
# |    explained_variance   | 0.437         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.137         |
# |    n_updates            | 5150          |
# |    policy_gradient_loss | -0.000117     |
# |    value_loss           | 0.276         |
# -------------------------------------------
# rew/r_total=1.42,rew/r_wood=0.81,rew/r_coal=0.07,rew/r_uranium=0.00,rew/r_research=0.44,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.10,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=158.00,game/research=176.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.81,game/coal_rate_mined=0.04,game/uranium_rate_mined=0.00
# rew/r_total=0.52,rew/r_wood=0.26,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.19,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.07,rew/r_units=-0.00,rew/r_city_tiles=0.00,game/turns=156.00,game/research=75.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.26,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.95e+03     |
# |    ep_rew_mean          | 7.19         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 150          |
# |    time_elapsed         | 3793         |
# |    total_timesteps      | 8470528      |
# | train/                  |              |
# |    approx_kl            | 0.0008568986 |
# |    clip_fraction        | 0.00685      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.206       |
# |    explained_variance   | 0.273        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.166        |
# |    n_updates            | 5160         |
# |    policy_gradient_loss | -0.000769    |
# |    value_loss           | 0.338        |
# ------------------------------------------
# rew/r_total=1.80,rew/r_wood=1.15,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.15,rew/r_units=-0.00,rew/r_city_tiles=0.00,game/turns=200.00,game/research=200.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=1.15,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+03     |
# |    ep_rew_mean          | 7.05         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 151          |
# |    time_elapsed         | 3819         |
# |    total_timesteps      | 8486912      |
# | train/                  |              |
# |    approx_kl            | 0.0011643493 |
# |    clip_fraction        | 0.00882      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | 0.397        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.14         |
# |    n_updates            | 5170         |
# |    policy_gradient_loss | 1.7e-05      |
# |    value_loss           | 0.281        |
# ------------------------------------------
# rew/r_total=14.52,rew/r_wood=1.37,rew/r_coal=0.80,rew/r_uranium=0.09,rew/r_research=0.50,rew/r_city_tiles_end=10.00,rew/r_fuel_collected=0.16,rew/r_units=0.60,rew/r_city_tiles=1.00,game/turns=360.00,game/research=200.00,game/unit_count=12.00,game/cart_count=0.00,game/city_count=6.00,game/city_tiles=10.00,game/wood_rate_mined=1.37,game/coal_rate_mined=0.40,game/uranium_rate_mined=0.02
# rew/r_total=2.89,rew/r_wood=1.09,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.46,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.15,rew/r_units=0.10,rew/r_city_tiles=0.10,game/turns=360.00,game/research=183.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=1.09,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2e+03        |
# |    ep_rew_mean          | 7.04         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 152          |
# |    time_elapsed         | 3844         |
# |    total_timesteps      | 8503296      |
# | train/                  |              |
# |    approx_kl            | 0.0013364035 |
# |    clip_fraction        | 0.00619      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | 0.406        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.105        |
# |    n_updates            | 5180         |
# |    policy_gradient_loss | -0.000202    |
# |    value_loss           | 0.212        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.02e+03      |
# |    ep_rew_mean          | 7.09          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 153           |
# |    time_elapsed         | 3869          |
# |    total_timesteps      | 8519680       |
# | train/                  |               |
# |    approx_kl            | 0.00051786035 |
# |    clip_fraction        | 0.000452      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.205        |
# |    explained_variance   | 0.66          |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0497        |
# |    n_updates            | 5190          |
# |    policy_gradient_loss | -0.000214     |
# |    value_loss           | 0.102         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.98e+03      |
# |    ep_rew_mean          | 7.46          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 154           |
# |    time_elapsed         | 3894          |
# |    total_timesteps      | 8536064       |
# | train/                  |               |
# |    approx_kl            | 0.00027575679 |
# |    clip_fraction        | 0.000171      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.267        |
# |    explained_variance   | 0.261         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.188         |
# |    n_updates            | 5200          |
# |    policy_gradient_loss | -0.000256     |
# |    value_loss           | 0.378         |
# -------------------------------------------
# rew/r_total=1.75,rew/r_wood=0.88,rew/r_coal=0.02,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.21,rew/r_units=0.15,rew/r_city_tiles=-0.00,game/turns=360.00,game/research=199.00,game/unit_count=3.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.88,game/coal_rate_mined=0.01,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.98e+03     |
# |    ep_rew_mean          | 7.63         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 155          |
# |    time_elapsed         | 3920         |
# |    total_timesteps      | 8552448      |
# | train/                  |              |
# |    approx_kl            | 0.0004105495 |
# |    clip_fraction        | 0.000134     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.215       |
# |    explained_variance   | 0.274        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.336        |
# |    n_updates            | 5210         |
# |    policy_gradient_loss | -0.000239    |
# |    value_loss           | 0.683        |
# ------------------------------------------
# rew/r_total=12.35,rew/r_wood=1.29,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=9.00,rew/r_fuel_collected=0.15,rew/r_units=0.50,rew/r_city_tiles=0.90,game/turns=360.00,game/research=200.00,game/unit_count=10.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=9.00,game/wood_rate_mined=1.29,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.97e+03      |
# |    ep_rew_mean          | 7.31          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 156           |
# |    time_elapsed         | 3945          |
# |    total_timesteps      | 8568832       |
# | train/                  |               |
# |    approx_kl            | 0.00062654656 |
# |    clip_fraction        | 0.00173       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.251        |
# |    explained_variance   | 0.271         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.208         |
# |    n_updates            | 5220          |
# |    policy_gradient_loss | -0.000331     |
# |    value_loss           | 0.419         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+03     |
# |    ep_rew_mean          | 7.15         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 157          |
# |    time_elapsed         | 3971         |
# |    total_timesteps      | 8585216      |
# | train/                  |              |
# |    approx_kl            | 0.0011005952 |
# |    clip_fraction        | 0.0032       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | 0.515        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.117        |
# |    n_updates            | 5230         |
# |    policy_gradient_loss | -0.000227    |
# |    value_loss           | 0.238        |
# ------------------------------------------
# rew/r_total=3.30,rew/r_wood=1.30,rew/r_coal=0.27,rew/r_uranium=0.00,rew/r_research=0.46,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.12,rew/r_units=0.05,rew/r_city_tiles=0.10,game/turns=360.00,game/research=185.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=1.30,game/coal_rate_mined=0.14,game/uranium_rate_mined=0.00
# rew/r_total=18.06,rew/r_wood=1.61,rew/r_coal=0.71,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=13.00,rew/r_fuel_collected=0.19,rew/r_units=0.75,rew/r_city_tiles=1.30,game/turns=360.00,game/research=200.00,game/unit_count=15.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=13.00,game/wood_rate_mined=1.61,game/coal_rate_mined=0.35,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.96e+03      |
# |    ep_rew_mean          | 7.31          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 158           |
# |    time_elapsed         | 3996          |
# |    total_timesteps      | 8601600       |
# | train/                  |               |
# |    approx_kl            | 7.4443975e-05 |
# |    clip_fraction        | 6.1e-06       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.262        |
# |    explained_variance   | 0.634         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0949        |
# |    n_updates            | 5240          |
# |    policy_gradient_loss | -0.00014      |
# |    value_loss           | 0.191         |
# -------------------------------------------
# rew/r_total=0.02,rew/r_wood=0.01,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=37.00,game/research=5.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=3.51,rew/r_wood=0.52,rew/r_coal=0.03,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.15,rew/r_units=0.10,rew/r_city_tiles=0.20,game/turns=360.00,game/research=200.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=2.00,game/wood_rate_mined=0.52,game/coal_rate_mined=0.02,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.91e+03      |
# |    ep_rew_mean          | 7.33          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 159           |
# |    time_elapsed         | 4022          |
# |    total_timesteps      | 8617984       |
# | train/                  |               |
# |    approx_kl            | 0.00066410244 |
# |    clip_fraction        | 0.0025        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.243        |
# |    explained_variance   | 0.281         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.223         |
# |    n_updates            | 5250          |
# |    policy_gradient_loss | -0.000188     |
# |    value_loss           | 0.449         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.94e+03     |
# |    ep_rew_mean          | 7.77         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 160          |
# |    time_elapsed         | 4047         |
# |    total_timesteps      | 8634368      |
# | train/                  |              |
# |    approx_kl            | 0.0007812553 |
# |    clip_fraction        | 0.00162      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.267       |
# |    explained_variance   | 0.428        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.163        |
# |    n_updates            | 5260         |
# |    policy_gradient_loss | -0.000579    |
# |    value_loss           | 0.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.91e+03     |
# |    ep_rew_mean          | 7.3          |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 161          |
# |    time_elapsed         | 4073         |
# |    total_timesteps      | 8650752      |
# | train/                  |              |
# |    approx_kl            | 0.0010055801 |
# |    clip_fraction        | 0.00839      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.272       |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.2          |
# |    n_updates            | 5270         |
# |    policy_gradient_loss | -0.000406    |
# |    value_loss           | 0.405        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.99e+03     |
# |    ep_rew_mean          | 7.47         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 162          |
# |    time_elapsed         | 4099         |
# |    total_timesteps      | 8667136      |
# | train/                  |              |
# |    approx_kl            | 0.0012814696 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.202       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0393       |
# |    n_updates            | 5280         |
# |    policy_gradient_loss | -0.000387    |
# |    value_loss           | 0.0826       |
# ------------------------------------------
# rew/r_total=1.27,rew/r_wood=0.72,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.41,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.14,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=239.00,game/research=165.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.72,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=1.07,rew/r_wood=0.66,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.35,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.06,rew/r_units=-0.00,rew/r_city_tiles=0.00,game/turns=232.00,game/research=139.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.66,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=9.88,rew/r_wood=0.55,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.11,rew/r_city_tiles_end=8.00,rew/r_fuel_collected=0.06,rew/r_units=0.35,rew/r_city_tiles=0.80,game/turns=120.00,game/research=45.00,game/unit_count=7.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=8.00,game/wood_rate_mined=0.55,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=10.41,rew/r_wood=1.55,rew/r_coal=0.18,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=7.00,rew/r_fuel_collected=0.13,rew/r_units=0.35,rew/r_city_tiles=0.70,game/turns=360.00,game/research=200.00,game/unit_count=7.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=7.00,game/wood_rate_mined=1.55,game/coal_rate_mined=0.09,game/uranium_rate_mined=0.00
# rew/r_total=1.01,rew/r_wood=0.61,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.33,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.07,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=191.00,game/research=132.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.61,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.02e+03     |
# |    ep_rew_mean          | 7.45         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 163          |
# |    time_elapsed         | 4124         |
# |    total_timesteps      | 8683520      |
# | train/                  |              |
# |    approx_kl            | 0.0006551307 |
# |    clip_fraction        | 0.00186      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.196       |
# |    explained_variance   | 0.388        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.303        |
# |    n_updates            | 5290         |
# |    policy_gradient_loss | -2.88e-05    |
# |    value_loss           | 0.61         |
# ------------------------------------------
# rew/r_total=0.93,rew/r_wood=0.47,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.36,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.10,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=279.00,game/research=142.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.47,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=19.43,rew/r_wood=1.37,rew/r_coal=0.33,rew/r_uranium=2.00,rew/r_research=0.50,rew/r_city_tiles_end=13.00,rew/r_fuel_collected=0.28,rew/r_units=0.65,rew/r_city_tiles=1.30,game/turns=360.00,game/research=200.00,game/unit_count=13.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=13.00,game/wood_rate_mined=1.37,game/coal_rate_mined=0.16,game/uranium_rate_mined=0.50
# rew/r_total=1.84,rew/r_wood=1.01,rew/r_coal=0.00,rew/r_uranium=0.14,rew/r_research=0.50,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.18,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=317.00,game/research=200.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=1.01,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.04
# rew/r_total=21.63,rew/r_wood=1.37,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=17.00,rew/r_fuel_collected=0.21,rew/r_units=0.85,rew/r_city_tiles=1.70,game/turns=273.00,game/research=200.00,game/unit_count=17.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=17.00,game/wood_rate_mined=1.37,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.02e+03     |
# |    ep_rew_mean          | 7.7          |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 164          |
# |    time_elapsed         | 4148         |
# |    total_timesteps      | 8699904      |
# | train/                  |              |
# |    approx_kl            | 0.0012952834 |
# |    clip_fraction        | 0.00536      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.182       |
# |    explained_variance   | 0.505        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.184        |
# |    n_updates            | 5300         |
# |    policy_gradient_loss | -0.000306    |
# |    value_loss           | 0.372        |
# ------------------------------------------
# rew/r_total=3.34,rew/r_wood=1.50,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.46,rew/r_city_tiles_end=1.00,rew/r_fuel_collected=0.18,rew/r_units=0.10,rew/r_city_tiles=0.10,game/turns=320.00,game/research=183.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=1.00,game/wood_rate_mined=1.50,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.01e+03      |
# |    ep_rew_mean          | 7.45          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 165           |
# |    time_elapsed         | 4173          |
# |    total_timesteps      | 8716288       |
# | train/                  |               |
# |    approx_kl            | 0.00012561845 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.133        |
# |    explained_variance   | 0.579         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.116         |
# |    n_updates            | 5310          |
# |    policy_gradient_loss | -5.48e-05     |
# |    value_loss           | 0.233         |
# -------------------------------------------
# rew/r_total=14.63,rew/r_wood=1.35,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=11.00,rew/r_fuel_collected=0.12,rew/r_units=0.55,rew/r_city_tiles=1.10,game/turns=360.00,game/research=200.00,game/unit_count=11.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=11.00,game/wood_rate_mined=1.35,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.08e+03     |
# |    ep_rew_mean          | 7.01         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 166          |
# |    time_elapsed         | 4198         |
# |    total_timesteps      | 8732672      |
# | train/                  |              |
# |    approx_kl            | 0.0006543911 |
# |    clip_fraction        | 0.00109      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.263       |
# |    explained_variance   | 0.522        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0695       |
# |    n_updates            | 5320         |
# |    policy_gradient_loss | -0.000434    |
# |    value_loss           | 0.142        |
# ------------------------------------------
# rew/r_total=0.12,rew/r_wood=0.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.01,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.00,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=360.00,game/research=5.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.03e+03      |
# |    ep_rew_mean          | 6.79          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 167           |
# |    time_elapsed         | 4223          |
# |    total_timesteps      | 8749056       |
# | train/                  |               |
# |    approx_kl            | 0.00087156263 |
# |    clip_fraction        | 0.00101       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.218        |
# |    explained_variance   | 0.755         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0499        |
# |    n_updates            | 5330          |
# |    policy_gradient_loss | -0.000438     |
# |    value_loss           | 0.104         |
# -------------------------------------------
# rew/r_total=5.56,rew/r_wood=1.38,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=3.00,rew/r_fuel_collected=0.18,rew/r_units=0.20,rew/r_city_tiles=0.30,game/turns=198.00,game/research=200.00,game/unit_count=4.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=3.00,game/wood_rate_mined=1.38,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.06e+03     |
# |    ep_rew_mean          | 6.81         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 168          |
# |    time_elapsed         | 4249         |
# |    total_timesteps      | 8765440      |
# | train/                  |              |
# |    approx_kl            | 0.0014941748 |
# |    clip_fraction        | 0.00682      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | 0.544        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0779       |
# |    n_updates            | 5340         |
# |    policy_gradient_loss | -0.000286    |
# |    value_loss           | 0.159        |
# ------------------------------------------
# rew/r_total=8.41,rew/r_wood=0.86,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=6.00,rew/r_fuel_collected=0.20,rew/r_units=0.25,rew/r_city_tiles=0.60,game/turns=360.00,game/research=200.00,game/unit_count=5.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=6.00,game/wood_rate_mined=0.86,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.14e+03      |
# |    ep_rew_mean          | 7.16          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 169           |
# |    time_elapsed         | 4275          |
# |    total_timesteps      | 8781824       |
# | train/                  |               |
# |    approx_kl            | 0.00014550202 |
# |    clip_fraction        | 0.00336       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.225        |
# |    explained_variance   | 0.348         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.227         |
# |    n_updates            | 5350          |
# |    policy_gradient_loss | -0.000417     |
# |    value_loss           | 0.459         |
# -------------------------------------------
# rew/r_total=19.08,rew/r_wood=0.95,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=15.00,rew/r_fuel_collected=0.33,rew/r_units=0.80,rew/r_city_tiles=1.50,game/turns=275.00,game/research=200.00,game/unit_count=16.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=15.00,game/wood_rate_mined=0.95,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.50,rew/r_wood=0.35,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.13,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.02,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=151.00,game/research=52.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.35,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=2.38,rew/r_wood=1.32,rew/r_coal=0.38,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.13,rew/r_units=0.05,rew/r_city_tiles=0.00,game/turns=360.00,game/research=200.00,game/unit_count=1.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=1.32,game/coal_rate_mined=0.19,game/uranium_rate_mined=0.00
# rew/r_total=4.12,rew/r_wood=1.16,rew/r_coal=0.30,rew/r_uranium=0.00,rew/r_research=0.31,rew/r_city_tiles_end=2.00,rew/r_fuel_collected=0.05,rew/r_units=0.10,rew/r_city_tiles=0.20,game/turns=360.00,game/research=123.00,game/unit_count=2.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=2.00,game/wood_rate_mined=1.16,game/coal_rate_mined=0.15,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.19e+03     |
# |    ep_rew_mean          | 7.5          |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 170          |
# |    time_elapsed         | 4300         |
# |    total_timesteps      | 8798208      |
# | train/                  |              |
# |    approx_kl            | 0.0008806438 |
# |    clip_fraction        | 0.00204      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.276        |
# |    n_updates            | 5360         |
# |    policy_gradient_loss | -9.67e-05    |
# |    value_loss           | 0.557        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.21e+03     |
# |    ep_rew_mean          | 7.71         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 171          |
# |    time_elapsed         | 4325         |
# |    total_timesteps      | 8814592      |
# | train/                  |              |
# |    approx_kl            | 0.0008119273 |
# |    clip_fraction        | 0.00309      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.289        |
# |    n_updates            | 5370         |
# |    policy_gradient_loss | -0.000239    |
# |    value_loss           | 0.584        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.23e+03     |
# |    ep_rew_mean          | 7.41         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 172          |
# |    time_elapsed         | 4351         |
# |    total_timesteps      | 8830976      |
# | train/                  |              |
# |    approx_kl            | 0.0008120303 |
# |    clip_fraction        | 0.00206      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | 0.494        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.204        |
# |    n_updates            | 5380         |
# |    policy_gradient_loss | -0.000259    |
# |    value_loss           | 0.414        |
# ------------------------------------------
# rew/r_total=17.37,rew/r_wood=1.37,rew/r_coal=0.59,rew/r_uranium=0.00,rew/r_research=0.24,rew/r_city_tiles_end=13.00,rew/r_fuel_collected=0.22,rew/r_units=0.65,rew/r_city_tiles=1.30,game/turns=158.00,game/research=97.00,game/unit_count=13.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=13.00,game/wood_rate_mined=1.37,game/coal_rate_mined=0.29,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.19e+03      |
# |    ep_rew_mean          | 7.26          |
# | time/                   |               |
# |    fps                  | 647           |
# |    iterations           | 173           |
# |    time_elapsed         | 4376          |
# |    total_timesteps      | 8847360       |
# | train/                  |               |
# |    approx_kl            | 0.00021947957 |
# |    clip_fraction        | 4.27e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.207        |
# |    explained_variance   | 0.722         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0415        |
# |    n_updates            | 5390          |
# |    policy_gradient_loss | -0.000122     |
# |    value_loss           | 0.0846        |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.19e+03     |
# |    ep_rew_mean          | 6.97         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 174          |
# |    time_elapsed         | 4402         |
# |    total_timesteps      | 8863744      |
# | train/                  |              |
# |    approx_kl            | 0.0004977832 |
# |    clip_fraction        | 0.000769     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | 0.584        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0964       |
# |    n_updates            | 5400         |
# |    policy_gradient_loss | -0.000212    |
# |    value_loss           | 0.196        |
# ------------------------------------------
# rew/r_total=24.96,rew/r_wood=1.23,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.49,rew/r_city_tiles_end=20.00,rew/r_fuel_collected=0.19,rew/r_units=1.05,rew/r_city_tiles=2.00,game/turns=198.00,game/research=197.00,game/unit_count=21.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=20.00,game/wood_rate_mined=1.23,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.2e+03      |
# |    ep_rew_mean          | 7.43         |
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 175          |
# |    time_elapsed         | 4427         |
# |    total_timesteps      | 8880128      |
# | train/                  |              |
# |    approx_kl            | 0.0010008162 |
# |    clip_fraction        | 0.00398      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.218       |
# ...
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.93e+03      |
# |    ep_rew_mean          | 6.14          |
# | time/                   |               |
# |    fps                  | 646           |
# |    iterations           | 355           |
# |    time_elapsed         | 8996          |
# |    total_timesteps      | 11829248      |
# | train/                  |               |
# |    approx_kl            | 0.00050927803 |
# |    clip_fraction        | 0.00128       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.226        |
# |    explained_variance   | 0.349         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.0971        |
# |    n_updates            | 7210          |
# |    policy_gradient_loss | -0.000203     |
# |    value_loss           | 0.199         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.91e+03     |
# |    ep_rew_mean          | 6.33         |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 356          |
# |    time_elapsed         | 9021         |
# |    total_timesteps      | 11845632     |
# | train/                  |              |
# |    approx_kl            | 0.0002832535 |
# |    clip_fraction        | 0.000165     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | 0.749        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.104        |
# |    n_updates            | 7220         |
# |    policy_gradient_loss | -0.000147    |
# |    value_loss           | 0.212        |
# ------------------------------------------
# rew/r_total=1.32,rew/r_wood=0.94,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.33,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.06,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=159.00,game/research=130.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.94,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.98e+03     |
# |    ep_rew_mean          | 6.03         |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 357          |
# |    time_elapsed         | 9046         |
# |    total_timesteps      | 11862016     |
# | train/                  |              |
# |    approx_kl            | 0.0007957432 |
# |    clip_fraction        | 0.00525      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.204        |
# |    n_updates            | 7230         |
# |    policy_gradient_loss | -0.000149    |
# |    value_loss           | 0.415        |
# ------------------------------------------
# rew/r_total=0.42,rew/r_wood=0.17,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.17,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.07,rew/r_units=0.00,rew/r_city_tiles=-0.00,game/turns=236.00,game/research=69.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.17,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+03    |
# |    ep_rew_mean          | 6.01        |
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 358         |
# |    time_elapsed         | 9072        |
# |    total_timesteps      | 11878400    |
# | train/                  |             |
# |    approx_kl            | 0.001348452 |
# |    clip_fraction        | 0.00447     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0318      |
# |    n_updates            | 7240        |
# |    policy_gradient_loss | -0.000434   |
# |    value_loss           | 0.0662      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.93e+03    |
# |    ep_rew_mean          | 5.55        |
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 359         |
# |    time_elapsed         | 9097        |
# |    total_timesteps      | 11894784    |
# | train/                  |             |
# |    approx_kl            | 0.000645676 |
# |    clip_fraction        | 0.00128     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.21       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.119       |
# |    n_updates            | 7250        |
# |    policy_gradient_loss | -8.16e-05   |
# |    value_loss           | 0.242       |
# -----------------------------------------
# rew/r_total=14.30,rew/r_wood=1.15,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.35,rew/r_city_tiles_end=11.00,rew/r_fuel_collected=0.16,rew/r_units=0.55,rew/r_city_tiles=1.10,game/turns=360.00,game/research=139.00,game/unit_count=11.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=11.00,game/wood_rate_mined=1.15,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.89e+03     |
# |    ep_rew_mean          | 5.67         |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 360          |
# |    time_elapsed         | 9123         |
# |    total_timesteps      | 11911168     |
# | train/                  |              |
# |    approx_kl            | 0.0016526661 |
# |    clip_fraction        | 0.00574      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.207       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0282       |
# |    n_updates            | 7260         |
# |    policy_gradient_loss | -0.000454    |
# |    value_loss           | 0.0597       |
# ------------------------------------------
# rew/r_total=1.67,rew/r_wood=1.05,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.12,rew/r_units=-0.00,rew/r_city_tiles=-0.00,game/turns=238.00,game/research=200.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=1.05,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.92e+03      |
# |    ep_rew_mean          | 5.56          |
# | time/                   |               |
# |    fps                  | 646           |
# |    iterations           | 361           |
# |    time_elapsed         | 9147          |
# |    total_timesteps      | 11927552      |
# | train/                  |               |
# |    approx_kl            | 0.00029629338 |
# |    clip_fraction        | 0.000159      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.191        |
# |    explained_variance   | 0.398         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.11          |
# |    n_updates            | 7270          |
# |    policy_gradient_loss | -0.000107     |
# |    value_loss           | 0.223         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.96e+03      |
# |    ep_rew_mean          | 5.94          |
# | time/                   |               |
# |    fps                  | 646           |
# |    iterations           | 362           |
# |    time_elapsed         | 9173          |
# |    total_timesteps      | 11943936      |
# | train/                  |               |
# |    approx_kl            | 0.00011761121 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.218        |
# |    explained_variance   | 0.228         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.137         |
# |    n_updates            | 7280          |
# |    policy_gradient_loss | -3.04e-05     |
# |    value_loss           | 0.276         |
# -------------------------------------------
# rew/r_total=1.29,rew/r_wood=0.66,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.13,rew/r_units=0.00,rew/r_city_tiles=0.00,game/turns=238.00,game/research=200.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.66,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=19.63,rew/r_wood=0.52,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.50,rew/r_city_tiles_end=16.00,rew/r_fuel_collected=0.16,rew/r_units=0.85,rew/r_city_tiles=1.60,game/turns=198.00,game/research=200.00,game/unit_count=17.00,game/cart_count=0.00,game/city_count=3.00,game/city_tiles=16.00,game/wood_rate_mined=0.52,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# rew/r_total=0.48,rew/r_wood=0.32,rew/r_coal=0.00,rew/r_uranium=0.00,rew/r_research=0.10,rew/r_city_tiles_end=0.00,rew/r_fuel_collected=0.06,rew/r_units=-0.00,rew/r_city_tiles=0.00,game/turns=119.00,game/research=40.00,game/unit_count=0.00,game/cart_count=0.00,game/city_count=0.00,game/city_tiles=0.00,game/wood_rate_mined=0.32,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.99e+03      |
# |    ep_rew_mean          | 6.25          |
# | time/                   |               |
# |    fps                  | 646           |
# |    iterations           | 363           |
# |    time_elapsed         | 9198          |
# |    total_timesteps      | 11960320      |
# | train/                  |               |
# |    approx_kl            | 0.00017553706 |
# |    clip_fraction        | 0.000128      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.165        |
# |    explained_variance   | 0.338         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.166         |
# |    n_updates            | 7290          |
# |    policy_gradient_loss | -0.000142     |
# |    value_loss           | 0.339         |
# -------------------------------------------
# rew/r_total=13.64,rew/r_wood=0.75,rew/r_coal=0.02,rew/r_uranium=0.00,rew/r_research=0.15,rew/r_city_tiles_end=11.00,rew/r_fuel_collected=0.08,rew/r_units=0.55,rew/r_city_tiles=1.10,game/turns=117.00,game/research=58.00,game/unit_count=11.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=11.00,game/wood_rate_mined=0.75,game/coal_rate_mined=0.01,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.96e+03      |
# |    ep_rew_mean          | 6.33          |
# | time/                   |               |
# |    fps                  | 646           |
# |    iterations           | 364           |
# |    time_elapsed         | 9223          |
# |    total_timesteps      | 11976704      |
# | train/                  |               |
# |    approx_kl            | 0.00082089705 |
# |    clip_fraction        | 0.00341       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.168        |
# |    explained_variance   | 0.167         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.316         |
# |    n_updates            | 7300          |
# |    policy_gradient_loss | -0.000119     |
# |    value_loss           | 0.639         |
# -------------------------------------------
# rew/r_total=5.92,rew/r_wood=0.66,rew/r_coal=0.11,rew/r_uranium=0.00,rew/r_research=0.33,rew/r_city_tiles_end=4.00,rew/r_fuel_collected=0.07,rew/r_units=0.35,rew/r_city_tiles=0.40,game/turns=360.00,game/research=133.00,game/unit_count=7.00,game/cart_count=0.00,game/city_count=1.00,game/city_tiles=4.00,game/wood_rate_mined=0.66,game/coal_rate_mined=0.05,game/uranium_rate_mined=0.00
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.95e+03      |
# |    ep_rew_mean          | 6.31          |
# | time/                   |               |
# |    fps                  | 646           |
# |    iterations           | 365           |
# |    time_elapsed         | 9248          |
# |    total_timesteps      | 11993088      |
# | train/                  |               |
# |    approx_kl            | 0.00026901465 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.199        |
# |    explained_variance   | 0.352         |
# |    learning_rate        | 0.0001        |
# |    loss                 | 0.141         |
# |    n_updates            | 7310          |
# |    policy_gradient_loss | -5.86e-05     |
# |    value_loss           | 0.284         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.92e+03     |
# |    ep_rew_mean          | 6.46         |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 366          |
# |    time_elapsed         | 9273         |
# |    total_timesteps      | 12009472     |
# | train/                  |              |
# |    approx_kl            | 0.0006617171 |
# |    clip_fraction        | 0.00143      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.232       |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0376       |
# |    n_updates            | 7320         |
# |    policy_gradient_loss | -0.000266    |
# |    value_loss           | 0.0782       |
# ------------------------------------------
# rew/r_total=5.76,rew/r_wood=0.55,rew/r_coal=0.01,rew/r_uranium=0.00,rew/r_research=0.16,rew/r_city_tiles_end=4.00,rew/r_fuel_collected=0.09,rew/r_units=0.55,rew/r_city_tiles=0.40,game/turns=198.00,game/research=63.00,game/unit_count=11.00,game/cart_count=0.00,game/city_count=2.00,game/city_tiles=4.00,game/wood_rate_mined=0.55,game/coal_rate_mined=0.00,game/uranium_rate_mined=0.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.91e+03     |
# |    ep_rew_mean          | 6.43         |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 367          |
# |    time_elapsed         | 9299         |
# |    total_timesteps      | 12025856     |
# | train/                  |              |
# |    approx_kl            | 0.0011460072 |
# |    clip_fraction        | 0.0033       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.199       |
# |    explained_variance   | 0.333        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.131        |
# |    n_updates            | 7330         |
# |    policy_gradient_loss | -0.00042     |
# |    value_loss           | 0.266        |
# ------------------------------------------
# Done training model.

# %%
# Save final model
model.save(path=f'models/model.zip')

print("Done training model.")
# Out:
# Done training model.

# %% [markdown]
# # Set up a Kaggle Submission and lux replay environment for the agent

# %%
"""
This downloads two required python package dependencies that are not pre-installed
by Kaggle yet.

This places the following two packages in the current working directory:
    luxai2021
    stable_baselines3
"""

import os
import shutil
import subprocess
import tempfile

def localize_package(git, branch, folder):
    if os.path.exists(folder):
        print("Already localized %s" % folder)
    else:
        # https://stackoverflow.com/questions/51239168/how-to-download-single-file-from-a-git-repository-using-python
        # Create temporary dir
        t = tempfile.mkdtemp()

        args = ['git', 'clone', '--depth=1', git, t, '-b', branch]
        res = subprocess.Popen(args, stdout=subprocess.PIPE)
        output, _error = res.communicate()

        if not _error:
            print(output)
        else:
            print(_error)

        # Copy desired file from temporary dir
        shutil.move(os.path.join(t, folder), '.')
        # Remove temporary dir
        shutil.rmtree(t, ignore_errors=True)

localize_package('https://github.com/glmcdona/LuxPythonEnvGym.git', 'main', 'luxai2021')
localize_package('https://github.com/glmcdona/LuxPythonEnvGym.git', 'main', 'kaggle_submissions')
localize_package('https://github.com/DLR-RM/stable-baselines3.git', 'master', 'stable_baselines3')
# Out:
# b''
# b''
# b''

# %%
# Move the dependent packages into kaggle submissions
# !mv luxai2021 kaggle_submissions
# !mv stable_baselines3 kaggle_submissions
# !rm ./kaggle_submissions/agent_policy.py
# !cp agent_policy.py kaggle_submissions

# Copy the agent and model to the submission
# !cp ./agent_policy.py kaggle_submissions
# !cp ./models/model.zip kaggle_submissions

# !ls kaggle_submissions
# Out:
# rm: cannot remove './kaggle_submissions/agent_policy.py': No such file or directory
# agent_policy.py		  luxai2021	       main.py	  stable_baselines3
# download_dependencies.py  main_lux-ai-2021.py  model.zip

# %%
from kaggle_environments import make
import json
# run another match but with our empty agent
env = make("lux_ai_2021", configuration={"seed": 5621242, "loglevel": 2, "annotations": True}, debug=True)

# Play the environment where the RL agent plays against itself
steps = env.run(["./kaggle_submissions/main.py", "./kaggle_submissions/main.py"])
# Out:
# 2024-03-04 05:41:46.857152: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 05:41:46.857325: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 05:41:46.859173: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-04 05:41:48.250363: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running in inference-only mode.
# 2024-03-04 05:41:54.899321: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 05:41:54.899475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 05:41:54.901344: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-04 05:41:56.447313: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Running in inference-only mode.
# [WARN] (match_UMfMPhbxT61C) - turn 29; Unit u_5 collided when trying to move n to (0, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 30; Unit u_6 collided when trying to move n to (1, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 31; Unit u_3 collided when trying to move w to (0, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 31; Unit u_6 collided when trying to move n to (1, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 32; Unit u_6 collided when trying to move n to (1, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 33; Unit u_6 collided when trying to move n to (1, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 35; Unit u_3 collided when trying to move n to (1, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 35; Unit u_5 collided when trying to move n to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 36; Unit u_3 collided when trying to move n to (1, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 37; Unit u_3 collided when trying to move n to (1, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 37; Unit u_5 collided when trying to move n to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 39; Unit u_2 collided when trying to move n to (10, 1)
# [WARN] (match_UMfMPhbxT61C) - turn 43; Unit u_4 collided when trying to move n to (10, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 47; Unit u_2 collided when trying to move s to (10, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 50; Unit u_8 collided when trying to move n to (0, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 51; Unit u_8 collided when trying to move n to (0, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 51; Unit u_4 collided when trying to move e to (10, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 53; Unit u_7 collided when trying to move s to (10, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 55; Unit u_2 collided when trying to move s to (10, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 57; Unit u_7 collided when trying to move s to (10, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 58; Unit u_1 collided when trying to move s to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 60; Unit u_1 collided when trying to move s to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 60; Unit u_2 collided when trying to move s to (10, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 61; Unit u_7 collided when trying to move s to (10, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 61; Unit u_2 collided when trying to move s to (10, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 62; Unit u_8 collided when trying to move n to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 63; Unit u_6 collided when trying to move w to (0, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 67; Unit u_8 collided when trying to move n to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 68; Unit u_8 collided when trying to move n to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 69; Unit u_6 collided when trying to move e to (3, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 69; Unit u_8 collided when trying to move n to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 70; Unit u_8 collided when trying to move n to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 70; Unit u_7 collided when trying to move e to (11, 1)
# [WARN] (match_UMfMPhbxT61C) - turn 71; Unit u_8 collided when trying to move n to (0, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 72; Unit u_11 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 73; Unit u_11 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 74; Unit u_11 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 76; Unit u_2 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 77; Unit u_2 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 78; Unit u_2 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 79; Unit u_2 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 80; Unit u_2 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 81; Unit u_9 collided when trying to move e to (3, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 81; Unit u_2 collided when trying to move s to (11, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 83; Unit u_9 collided when trying to move e to (3, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 83; Unit u_2 collided when trying to move s to (11, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 84; Unit u_9 collided when trying to move e to (3, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 85; Unit u_9 collided when trying to move e to (3, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 85; Unit u_7 collided when trying to move s to (11, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 86; Unit u_9 collided when trying to move e to (3, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 87; Unit u_9 collided when trying to move e to (3, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 87; Unit u_11 collided when trying to move s to (11, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 89; Unit u_14 collided when trying to move e to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 89; Unit u_2 collided when trying to move e to (11, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 89; Unit u_4 collided when trying to move n to (12, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 90; Unit u_14 collided when trying to move e to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 90; Unit u_2 collided when trying to move e to (11, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 90; Unit u_12 collided when trying to move e to (12, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 91; Unit u_12 collided when trying to move e to (12, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 92; Unit u_14 collided when trying to move e to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 92; Unit u_4 collided when trying to move n to (12, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 92; Unit u_12 collided when trying to move e to (12, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 93; Unit u_9 collided when trying to move s to (4, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 93; Unit u_14 collided when trying to move e to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 93; Unit u_12 collided when trying to move e to (12, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 94; Unit u_3 collided when trying to move n to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 94; Unit u_4 collided when trying to move n to (12, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 96; Unit u_14 collided when trying to move e to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 96; Unit u_12 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 97; Unit u_12 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 98; Unit u_3 collided when trying to move n to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 98; Unit u_12 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 99; Unit u_12 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 100; Unit u_14 collided when trying to move e to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 100; Unit u_12 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 101; Unit u_12 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 102; Unit u_10 collided when trying to move n to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 103; Unit u_10 collided when trying to move n to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 103; Unit u_13 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 104; Unit u_10 collided when trying to move n to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 104; Unit u_14 collided when trying to move e to (4, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 104; Unit u_13 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 105; Unit u_10 collided when trying to move n to (4, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 105; Unit u_14 collided when trying to move e to (4, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 105; Unit u_13 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 105; Unit u_27 collided when trying to move s to (14, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 106; Unit u_3 collided when trying to move e to (5, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 106; Unit u_14 collided when trying to move e to (4, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 106; Unit u_13 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 107; Unit u_3 collided when trying to move e to (5, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 107; Unit u_14 collided when trying to move e to (4, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 107; Unit u_7 collided when trying to move e to (14, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 107; Unit u_13 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 108; Unit u_14 collided when trying to move e to (4, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 108; Unit u_13 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 109; Unit u_4 collided when trying to move n to (15, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 109; Unit u_13 collided when trying to move e to (13, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 115; Unit u_2 collided when trying to move s to (14, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 116; Unit u_2 collided when trying to move s to (14, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 117; Unit u_2 collided when trying to move s to (14, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 119; Unit u_36 collided when trying to move s to (14, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 120; Unit u_6 collided when trying to move e to (5, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 120; Unit u_9 collided when trying to move e to (5, 1)
# [WARN] (match_UMfMPhbxT61C) - turn 121; Unit u_3 collided when trying to move e to (5, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 121; Unit u_9 collided when trying to move e to (5, 1)
# [WARN] (match_UMfMPhbxT61C) - turn 122; Unit u_3 collided when trying to move e to (5, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 123; Unit u_7 collided when trying to move e to (14, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 125; Unit u_4 collided when trying to move n to (15, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 125; Unit u_19 collided when trying to move e to (15, 2)
# [WARN] (match_UMfMPhbxT61C) - turn 127; Unit u_19 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 129; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 131; Unit u_4 collided when trying to move e to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 131; Unit u_34 collided when trying to move e to (15, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 132; Unit u_16 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 132; Unit u_34 collided when trying to move e to (15, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 133; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 133; Unit u_34 collided when trying to move e to (15, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 134; Unit u_20 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 134; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 135; Unit u_20 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 135; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 135; Unit u_7 collided when trying to move e to (15, 4)
# [WARN] (match_UMfMPhbxT61C) - turn 136; Unit u_20 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 136; Unit u_21 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 137; Unit u_20 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 138; Unit u_19 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 140; Unit u_14 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 140; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 140; Unit u_39 collided when trying to move s to (14, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 141; Unit u_14 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 142; Unit u_3 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 142; Unit u_21 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 142; Unit u_39 collided when trying to move s to (14, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 143; Unit u_3 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 143; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 143; Unit u_39 collided when trying to move s to (14, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 144; Unit u_39 collided when trying to move s to (14, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 145; Unit u_3 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 145; Unit u_21 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 145; Unit u_39 collided when trying to move s to (14, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 146; Unit u_3 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 147; Unit u_3 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 147; Unit u_20 collided when trying to move s to (4, 7)
# [WARN] (match_UMfMPhbxT61C) - turn 147; Unit u_21 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 147; Unit u_39 collided when trying to move s to (14, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 148; Unit u_3 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 148; Unit u_19 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 148; Unit u_39 collided when trying to move s to (14, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 149; Unit u_3 collided when trying to move s to (4, 5)
# [WARN] (match_UMfMPhbxT61C) - turn 149; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 160; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 161; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 162; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 163; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 164; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 165; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 166; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 167; Unit u_19 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 168; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 169; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 170; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 171; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 172; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 173; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 174; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 175; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 176; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 177; Unit u_21 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 178; Unit u_19 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 179; Unit u_19 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 180; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 181; Unit u_19 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 182; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 183; Unit u_7 collided when trying to move n to (13, 12)
# [WARN] (match_UMfMPhbxT61C) - turn 183; Unit u_36 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 184; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 185; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 187; Unit u_19 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 188; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 188; Unit u_21 collided when trying to move s to (14, 7)
# [WARN] (match_UMfMPhbxT61C) - turn 189; Unit u_2 collided when trying to move s to (15, 3)
# [WARN] (match_UMfMPhbxT61C) - turn 189; Unit u_21 collided when trying to move s to (14, 7)
# [WARN] (match_UMfMPhbxT61C) - turn 190; Unit u_21 collided when trying to move s to (14, 7)

# %%
# Render the match
env.render(mode="ipython", width=1200, height=800)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;e1da9342-d9e9-11ee-8d89-0242ac1c000c&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 5621242,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;width&quot;: -1,
#       &quot;height&quot;: -1
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;integer&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 16,
#             &quot;height&quot;: 16,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;16 16&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 3 800&quot;,
#               &quot;r wood 0 4 800&quot;,
#               &quot;r coal 0 6 405&quot;,
#               &quot;r coal 0 7 368&quot;,
#               &quot;r uranium 0 15 338&quot;,
#               &quot;r wood 1 4 800&quot;,
#               &quot;r wood 1 13 349&quot;,
#               &quot;r wood 2 11 354&quot;,
#               &quot;r wood 2 12 368&quot;,
#               &quot;r wood 3 3 374&quot;,
#               &quot;r wood 3 11 381&quot;,
#               &quot;r wood 3 12 376&quot;,
#               &quot;r wood 4 2 337&quot;,
#               &quot;r wood 4 3 391&quot;,
#               &quot;r wood 5 2 393&quot;,
#               &quot;r wood 5 3 375&quot;,
#               &quot;r coal 7 15 391&quot;,
#               &quot;r coal 8 15 391&quot;,
#               &quot;r wood 10 2 393&quot;,
#               &quot;r wood 10 3 375&quot;,
#               &quot;r wood 11 2 337&quot;,
#               &quot;r wood 11 3 391&quot;,
#               &quot;r wood 12 3 374&quot;,
#               &quot;r wood 12 11 381&quot;,
#               &quot;r wood 12 12 376&quot;,
#               &quot;r wood 13 11 354&quot;,
#               &quot;r wood 13 12 368&quot;,
#               &quot;r wood 14 4 800&quot;,
#               &quot;r wood 14 13 349&quot;,

# %% [markdown]
# # Prepare and submit the kaggle submission

# %%
# !tar -czf submission.tar.gz -C kaggle_submissions .
# !ls
# Out:
# agent_policy.py     log.txt	     models	  sample_data
# kaggle_submissions  lux_tensorboard  __pycache__  submission.tar.gz
